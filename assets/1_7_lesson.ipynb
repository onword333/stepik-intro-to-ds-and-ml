# %% [markdown]
# # Визуализация

# %%
import pandas as pd
import numpy as np

#%matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

students = pd.read_csv('StudentsPerformance.csv')
salary = pd.read_csv('data/income.csv')
dataset_209770_6 = pd.read_csv('data/dataset_209770_6 (3).txt', sep=' ')

# %% [markdown]
# Гистрограмма

# %%
# задает пределы
#students.plot(ylim=(0,1000))

students['math score'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Точечная диаграмма (график корреляции между двумя переменными)
# Результат math score и reading score: линейная взаимосвязь переменных

# %%
students.plot.scatter(x = 'math score', y = 'reading score')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %% [markdown]
# Seaborn, точечная диаграмма
# Показывает регриссионную прямую, которая показывает линейную аппроксимацию взаимосвязи двух переменных

# %%
# hue - группирующая переменная
# fit_reg - убирает регрессионые прямые
ax = sns.lmplot(x = 'math score', y = 'reading score', data=students, hue='gender', fit_reg=False)

# кастомизация графика
ax.set_xlabels('My math score')

# %% [markdown]
# ## Шаг 5, задание
# Представьте, что у вас есть датафрэйм df, хранящий данные о зарплате за месяц, со всего 1-ой колонкой income.
#
# Укажите верные способы, как отрисовать простой график зависимости зарплаты от даты (то, как отображается дата сейчас не важно, главное сам график)
#
# Убедитесь, что вы используте версию seaborn > = 0.9.
#
# Ответ: все варианты ниже

# %%
sns.lineplot(x = salary.index, y = salary.income)
#sns.lineplot(data=salary)
#salary.plot()
#plt.plot(salary.index,salary.income)
#salary['income'].plot()
#salary.plot(kind='line')
#salary.income.plot()
# Out:
# <Axes: ylabel='income'>

# %% [markdown]
# ## Шаг 6, задание
# Вам дан датасэт с 2-мя фичами (колонками). Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных (одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.
#
# В ответе вы должны указать число кластеров в виде числа (например: 3).
#
# Ответ: 7

# %%
#sns.lmplot(x=dataset_209770_6.x, y=dataset_209770_6.y, data=dataset_209770_6)
dataset_209770_6.plot.scatter(x = 'x', y = 'y')
# Out:
# <Axes: xlabel='x', ylabel='y'>
